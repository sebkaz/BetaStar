# %%
df = catalog.load('graph_pre')
# Out:
# [12/08/23 13:50:28] INFO     Loading data from 'graph_pre' (CSVDataSet)...                      ]8;id=810626;file:///Users/air/Desktop/BetaStar/env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=626614;file:///Users/air/Desktop/BetaStar/env/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\

# %%
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    in    out
# 0   0  16494
# 1   1   2788
# 2   1   3653
# 3   1   3677
# 4   1   4902
